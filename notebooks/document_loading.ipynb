# %%
pip install -U langchain-community pypdf
# Out:
# Requirement already satisfied: langchain-community in c:\users\niharika\hackathon rag\venv\lib\site-packages (0.4.2)
# Requirement already satisfied: pypdf in c:\users\niharika\hackathon rag\venv\lib\site-packages (6.13.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (1.4.7)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (0.8.16)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.17)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.5.20)
# Requirement already satisfied: greenlet>=1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.1)
# Requirement already satisfied: anyio in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.0)
# Requirement already satisfied: httpcore==1.* in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
from pathlib import Path

# %%
PROBLEM_FOLDER = "../data/problem_statements"
WINNING_FOLDER = "../data/winning_projects"

all_documents = []

# Load Problem Statements
for pdf_file in Path(PROBLEM_FOLDER).glob("*.pdf"):
    loader = PyPDFLoader(str(pdf_file))
    documents = loader.load()
    all_documents.extend(documents)

# Load Winning Projects
for pdf_file in Path(WINNING_FOLDER).glob("*.pdf"):
    loader = PyPDFLoader(str(pdf_file))
    documents = loader.load()
    all_documents.extend(documents)

print(f"Total Documents Loaded: {len(all_documents)}")
# Out:
# Total Documents Loaded: 65

# %%
all_documents[0]
# Out:
# Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20200104110004', 'source': '..\\data\\problem_statements\\problem_statement_1.pdf', 'total_pages': 16, 'page': 0, 'page_label': '1'}, page_content='SIH Problem Statements (Software Category)\nS. No.P S Number Domain Bucket Problem Statement title Organisation\n1 AD358 Sustainable Environment GIS BASED FLOOD RISK ASSESSMENTEducation department Gujarat\n2 AD358 Software - Web App developmentRoad maintenance record-keeping systemEducation department Gujarat\n3 AG343 Energy / Renewable EnergyRenewable Energy forecasting, for an \nintegrated smart grid MathWorks\n4 AG51 Waste Management Smart Management of Food Storage and \nWaste Reduction\nment of Scientific and Industrial \nResearch\n5 AJ128 Energy / Renewable EnergyTechnological advances for Retail OutletsMinistry of Petroleum and Natural \nGas\n6 AJ129 Smart Communication Technological advances for Retail OutletsMinistry of Petroleum and Natural \nGas\n7 AK10 Software - Web App developmentRating an Airport Mapping DatabaseAirports Authority of india\n8 AK11 Software - Web App development\nA web based software is sought for fail-free \noperations of various CNS/ATM facilities, \npreventive maintenance is carried out on \ndaily, weekly, monthly, six-montly and \nannual basis.\nAirports Authority of india\n9 AK12 Software - Mobile App \ndevelopment\nA Mobile based Inventory Management \nSystem using QR code applicationAirports Authority of india\n10 AK14 Software - Web App development\nA visual Dashboard based on data analytics \nfor percentage utilization of Airport facilities \nand utilities using IOT.\norts Authority of india\n11 AK14 Software - Mobile App \ndevelopment\nAn Mobile based Dwell time Management \nSystem using IOT. Airports Authority of india\n12 AK15 Software - Web App developmentKnowledge Management System through \nBlock Chain Airports Authority of india\n13 AK16 Software - Mobile App \ndevelopment\nMobile Application based Passenger \nfacilitation System using Artificial \nIntelligence and Machine learning\nAirports Authority of india\n14 AK209 Software - Web App development\nCreating Ability to Server Logs Management \nfor Analysis & Report of Heterogeneous \nServers\nBEML Limited\n15 AK210 Smart Vehicles Design of Energy Efficient Regenerative \nHydraulic System for 100 Ton ExcavatorBEML Limited\n16 AK211 Smart Vehicles BH60M and BH100 with Electronic \nTransmission BEML Limited')

# %%
all_documents[0].page_content[:500]
# Out:
# 'SIH Problem Statements (Software Category)\nS. No.P S Number Domain Bucket Problem Statement title Organisation\n1 AD358 Sustainable Environment GIS BASED FLOOD RISK ASSESSMENTEducation department Gujarat\n2 AD358 Software - Web App developmentRoad maintenance record-keeping systemEducation department Gujarat\n3 AG343 Energy / Renewable EnergyRenewable Energy forecasting, for an \nintegrated smart grid MathWorks\n4 AG51 Waste Management Smart Management of Food Storage and \nWaste Reduction\nment of Sci'

# %%
print(all_documents[4].page_content[:1000])
# Out:
# 58 CK132 Smart Communication
# Timing error estimation and matched
# filtering are crucial processing blocks in a
# communication receiver. The problem is like
# looking for the occurrence of a known signal
# in the observed/measured signal, which is
# noisy and distorted. This nature of problem
# makes it best suited for intelligent approach,
# as human brain invariably solves this kind of
# problem in day-to-day life. Classical
# techniques like maximum likelihood, Early-
# Late, Gardener and Muller approaches have
# been successfully implemented. However, it
# is perceived that machine learning
# techniques will outperform the classical
# approaches and this fact needs to be
# researched. The neural network shall use
# minimum computation and converge fast for
# practical and real-time implementation. If
# the results are promising, it can be applied
# for military and commercial radars.
# Dte of IT & Cyber Security, DRDO
# 59 CK139 Software - Web App developmentIndoor Navigation App Dte of IT & Cyber Securi

# %%
print(all_documents[50].page_content[:1000])
# Out:
#  Search hackathons...  Log inSign up
# Join a hackathon  
# Devpost
# Participate in our public hackathons
# Hackathons  Projects 
# Devpost for Teams
# Access your company's private hackathons
# Login Host a hackathon  
# Devpost
# Grow your developer ecosystem and promote your platform
# Host a public hackathon 
# Devpost for Teams
# Drive innovation, collaboration, and retention within your organization
# Host an internal hackathon 
# By use case
# AI hackathons  Customer hackathons  Employee hackathons  Public hackathons Resources  
# Blog
# Insights into hackathon planning and participation
# Customer stories
# Inspiration from peers and other industry leaders
# Planning guides
# Best practices for planning online and in-person hackathons
# Webinars & events
# Upcoming events and on-demand recordings
# Help desk
# Common questions and support documentation
# 6/17/26, 6:46 PM Neuthera - Drug discovery toolkit | Devpost
# https://devpost.com/software/neuthera-drug-discovery-platform 1/8

# %%
print(all_documents[0].metadata)
# Out:
# {'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20200104110004', 'source': '..\\data\\problem_statements\\problem_statement_1.pdf', 'total_pages': 16, 'page': 0, 'page_label': '1'}

# %%
print(all_documents[-1].metadata)
# Out:
# {'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-06-17T13:15:31+00:00', 'title': 'Snapdragon AI: Multilingual Translator | Devpost', 'moddate': '2026-06-17T13:15:31+00:00', 'source': '..\\data\\winning_projects\\snapdragon.pdf', 'total_pages': 7, 'page': 6, 'page_label': '7'}

# %%
pip install -U langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\niharika\hackathon rag\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-text-splitters) (1.4.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.16)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: anyio in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.14.0)
# Requirement already satisfied: certifi in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitters = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 200
)
chunks = text_splitters.split_documents(all_documents)

# %%
len(chunks)
# Out:
# 571

# %%
chunks[0].metadata
# Out:
# {'producer': 'PDFium',
#  'creator': 'PDFium',
#  'creationdate': 'D:20200104110004',
#  'source': '..\\data\\problem_statements\\problem_statement_1.pdf',
#  'total_pages': 16,
#  'page': 0,
#  'page_label': '1'}

# %%
chunks[0].page_content
# Out:
# 'SIH Problem Statements (Software Category)\nS. No.P S Number Domain Bucket Problem Statement title Organisation\n1 AD358 Sustainable Environment GIS BASED FLOOD RISK ASSESSMENTEducation department Gujarat\n2 AD358 Software - Web App developmentRoad maintenance record-keeping systemEducation department Gujarat\n3 AG343 Energy / Renewable EnergyRenewable Energy forecasting, for an \nintegrated smart grid MathWorks\n4 AG51 Waste Management Smart Management of Food Storage and \nWaste Reduction\nment of Scientific and Industrial \nResearch\n5 AJ128 Energy / Renewable EnergyTechnological advances for Retail OutletsMinistry of Petroleum and Natural \nGas\n6 AJ129 Smart Communication Technological advances for Retail OutletsMinistry of Petroleum and Natural \nGas\n7 AK10 Software - Web App developmentRating an Airport Mapping DatabaseAirports Authority of india\n8 AK11 Software - Web App development\nA web based software is sought for fail-free \noperations of various CNS/ATM facilities,'

# %%
chunks[1].page_content
# Out:
# '8 AK11 Software - Web App development\nA web based software is sought for fail-free \noperations of various CNS/ATM facilities, \npreventive maintenance is carried out on \ndaily, weekly, monthly, six-montly and \nannual basis.\nAirports Authority of india\n9 AK12 Software - Mobile App \ndevelopment\nA Mobile based Inventory Management \nSystem using QR code applicationAirports Authority of india\n10 AK14 Software - Web App development\nA visual Dashboard based on data analytics \nfor percentage utilization of Airport facilities \nand utilities using IOT.\norts Authority of india\n11 AK14 Software - Mobile App \ndevelopment\nAn Mobile based Dwell time Management \nSystem using IOT. Airports Authority of india\n12 AK15 Software - Web App developmentKnowledge Management System through \nBlock Chain Airports Authority of india\n13 AK16 Software - Mobile App \ndevelopment\nMobile Application based Passenger \nfacilitation System using Artificial \nIntelligence and Machine learning\nAirports Authority of india'

# %%
import getpass
import os

if not os.getenv("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API key: ")

# %%
# !pip install sentence-transformers
# !pip install langchain-huggingface
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\niharika\hackathon rag\venv\lib\site-packages (5.6.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sentence-transformers) (5.12.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sentence-transformers) (1.20.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sentence-transformers) (2.12.1)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sentence-transformers) (2.4.6)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sentence-transformers) (1.18.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sentence-transformers) (4.68.3)
# Requirement already satisfied: click>=8.4.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: colorama in c:\users\niharika\hackathon rag\venv\lib\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: anyio in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.14.0)
# Requirement already satisfied: certifi in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.1.2)
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-huggingface in c:\users\niharika\hackathon rag\venv\lib\site-packages (1.2.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-huggingface) (1.20.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-huggingface) (1.4.7)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: click>=8.4.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.68.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.8.16)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.16.1)
# Requirement already satisfied: colorama in c:\users\niharika\hackathon rag\venv\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: anyio in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.14.0)
# Requirement already satisfied: certifi in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.0.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\niharika\hackathon rag\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.1.2)
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-small-en-v1.5"
)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 2375.24it/s]

# %%
vector = embeddings.embed_query(
    "Crop disease detection using AI"
)

print(len(vector))
print(vector[:10])
# Out:
# 384
# [-0.030386315658688545, -0.0031176824122667313, 0.04321253299713135, 0.010382000356912613, 0.10868684202432632, -0.03727182000875473, 0.03397485241293907, 0.01783464476466179, 0.031807251274585724, 0.013321240432560444]

# %%
from langchain_qdrant import QdrantVectorStore

vector_store = QdrantVectorStore.from_documents(
    documents=chunks,
    embedding=embeddings,
    url="http://localhost:6333",
    collection_name="hackathon_docs"
)

# %%
retriever = vector_store.as_retriever(
    search_kwargs={"k": 5}
)

# %%
query = "AI projects for agriculture"

results = retriever.invoke(query)

# %%
len(results)
# Out:
# 5

# %%
results[0].page_content
# Out:
# 'SIH1638 AI-Driven Crop Disease Prediction and Management System Software Agriculture, FoodTech & Rural DevelopmentNULL Background: Crop diseases can devastate yields, leading to significant financial losses for farmers. Early detection and timely intervention are crucial for effective management. Description: Develop an AI-driven system that analyzes crop images and environmental data to predict potential disease outbreaks. This system will provide farmers with actionable insights and treatment recommendations to mitigate risks. Expected Solution: A mobile and web-based application that utilizes machine learning algorithms to identify crop diseases and suggest preventive measures and treatments based on real-time data.Indian Council of Agricultural Research (ICAR)Ministry of Agriculture and Farmers Welfare'

# %%
results[0].metadata
# Out:
# {'producer': 'Microsoft® Excel® 2021',
#  'creator': 'Microsoft® Excel® 2021',
#  'creationdate': '2026-06-17T19:20:00+05:30',
#  'title': 'Data',
#  'author': 'Siddhartha Sharma',
#  'moddate': '2026-06-17T19:20:00+05:30',
#  'source': '..\\data\\problem_statements\\problem_statement_2.pdf',
#  'total_pages': 4,
#  'page': 1,
#  'page_label': '2',
#  '_id': 'c9a0a409-30b2-47e4-b9f6-5fe9510b7c6a',
#  '_collection_name': 'hackathon_docs'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("""
Answer the question using the provided context.

Context:
{context}

Question:
{question}
""")


def ask_rag(question):

    docs = retriever.invoke(question)

    context = "\n\n".join(
        doc.page_content for doc in docs
    )

    final_prompt = prompt.format(
        context=context,
        question=question
    )

    response = llm.invoke(final_prompt)

    sources = []

    for doc in docs:
        source = doc.metadata.get("source", "Unknown")
        page = doc.metadata.get("page", "N/A")

        sources.append(
            f"{source} (Page {page})"
        )

    return {
        "answer": response.content,
        "sources": list(set(sources))
    }

# %%
result = ask_rag(
    "Suggest healthcare hackathon ideas"
)

print(result["answer"])

print("\nSources:")

for source in result["sources"]:
    print(source)
# Out:
# Based on the provided context, here are a few healthcare hackathon ideas:
#
# 1.  **Geriatric Care Products Hackathon:** Design and develop products that enhance the independence, well-being, and dignity of the elderly, focusing on areas like mobility and accessibility (e.g., advanced walking aids, wheelchair innovations).
# 2.  **Delivery Worker Well-being Hackathon:** Design solutions that address the challenges faced by delivery workers, specifically improving their safety, efficiency, health, and overall job satisfaction.
#
# Sources:
# ..\data\problem_statements\problem_statement_2.pdf (Page 3)

# %%
def generate_project_ideas(domain):

    query = f"""
    Generate 5 innovative hackathon project ideas for {domain}.

    For each idea provide:
    - Problem
    - Solution
    - Innovation
    - Expected Impact
    """

    return ask_rag(query)

# %%
def recommend_tech_stack(project):

    query = f"""
    Recommend the best technology stack for:

    {project}

    Include:
    - Frontend
    - Backend
    - Database
    - AI/ML Tools
    - Deployment
    - APIs
    """

    return ask_rag(query)

# %%
def generate_roadmap(project):

    query = f"""
    Create a hackathon development roadmap for:

    {project}

    Include:
    - Planning
    - Development
    - Testing
    - Deployment
    - Presentation Preparation

    Give a timeline.
    """

    return ask_rag(query)

# %%
def generate_architecture(project):

    query = f"""
    Design a complete system architecture for:

    {project}

    Include:
    - Components
    - User Flow
    - Database Flow
    - APIs
    - AI Components
    - Deployment Architecture

    Explain clearly.
    """

    return ask_rag(query)

# %%
def generate_elevator_pitch(project):

    query = f"""
    Generate a 45-second elevator pitch for:

    {project}

    Include:
    - Problem
    - Solution
    - Impact
    - Closing Statement
    """

    return ask_rag(query)

# %%
def generate_judge_questions(project):

    query = f"""
    Generate 15 hackathon judge questions for:

    {project}

    Also provide strong answers for each question.
    """

    return ask_rag(query)

# %%
print(
    generate_project_ideas("Healthcare")
)

print(
    recommend_tech_stack(
        "AI Crop Disease Detection"
    )
)

print(
    generate_architecture(
        "AI Crop Disease Detection"
    )
)

print(
    generate_elevator_pitch(
        "AI Crop Disease Detection"
    )
)
# Out:
# {'answer': 'Here are 5 innovative hackathon project ideas for Healthcare, complete with Problem, Solution, Innovation, and Expected Impact:\n\n---\n\n**1. AI-Powered Mental Health Support for Healthcare Professionals**\n\n*   **Problem:** Frontline healthcare workers experience exceptionally high rates of stress, burnout, anxiety, and depression due to demanding work environments, long hours, and exposure to trauma. Existing support systems are often stigmatized, inaccessible, or overwhelmed.\n*   **Solution:** A confidential, AI-powered mobile application designed specifically for healthcare professionals, offering real-time emotional support, personalized stress management techniques, anonymous peer support groups, and quick access to professional counseling resources.\n*   **Innovation:** Leverages natural language processing (NLP) and sentiment analysis to understand a user\'s emotional state and provide context-aware coping strategies, mindfulness exercises, and psychoeducation. It also includes a secure, anonymized peer-to-peer forum for shared experiences and mutual support, breaking down stigma barriers.\n*   **Expected Impact:** Reduced rates of burnout and mental health issues among healthcare professionals, improved job satisfaction and retention, leading to a more resilient and compassionate healthcare workforce and ultimately better patient care.\n\n---\n\n**2. Personalized Chronic Disease Management via Wearables & Predictive AI**\n\n*   **Problem:** Patients with chronic diseases (e.g., diabetes, hypertension, heart failure) often struggle with adherence to treatment plans, lifestyle modifications, and proactive self-management, leading to frequent complications and hospital readmissions.\n*   **Solution:** A comprehensive platform that integrates data from various wearable sensors (smartwatches, continuous glucose monitors, smart scales) with AI analytics to provide personalized, predictive insights and adaptive management plans. The system alerts patients and caregivers to potential issues before they become critical.\n*   **Innovation:** Goes beyond simple data logging by employing machine learning algorithms to identify subtle patterns and predict health deteriorations (e.g., impending hypoglycemic events, hypertension spikes) based on individual physiological data, lifestyle, and medical history. It then delivers proactive, personalized recommendations for diet, exercise, and medication adjustments.\n*   **Expected Impact:** Improved patient adherence and engagement in self-management, reduced chronic disease complications, fewer emergency room visits and hospitalizations, leading to better long-term health outcomes and significant cost savings for healthcare systems.\n\n---\n\n**3. Accessible Tele-Rehabilitation with AI-Guided Motion Tracking**\n\n*   **Problem:** Many patients, especially those in rural areas or with mobility limitations, face significant barriers to accessing consistent and high-quality physical or occupational therapy, hindering their recovery post-injury, surgery, or stroke.\n*   **Solution:** A low-cost, AI-guided tele-rehabilitation system that allows patients to perform prescribed exercises at home. Utilizing a standard smartphone or webcam, AI-powered computer vision tracks their movements, provides real-time feedback on form, and monitors progress, connecting them remotely with their therapist.\n*   **Innovation:** Eliminates the need for expensive specialized sensors or equipment by using readily available camera technology and advanced AI to accurately assess joint angles, range of motion, and exercise technique. It offers gamified elements to boost patient motivation and adherence, while therapists can remotely review performance data and adjust plans.\n*   **Expected Impact:** Increased access to effective rehabilitation services for underserved populations, improved recovery rates and functional independence, reduced travel burden and costs for patients, and optimized therapi ...
# {'answer': 'Based on the provided context, which emphasizes an AI-driven system for crop disease diagnosis using leaf images, providing disease information and solutions, and being accessible via mobile and web, here\'s a recommended technology stack:\n\n**AI Crop Disease Detection Technology Stack:**\n\n*   **Frontend (User Interface - Mobile & Web)**\n    *   **Mobile:** **React Native** or **Flutter** (for cross-platform development, allowing a single codebase for both iOS and Android apps, efficiently addressing the "mobile-based application" requirement).\n    *   **Web:** **React.js** or **Vue.js** (modern JavaScript frameworks for building interactive and responsive web applications, suitable for the "web-based application" requirement).\n    *   **Reasoning:** These frameworks offer excellent user experience, component reusability, and strong community support, crucial for an application requiring image input and dynamic content display.\n\n*   **Backend (Application Logic & API)**\n    *   **Language & Framework:** **Python with FastAPI** or **Flask**\n    *   **Reasoning:** Python is the dominant language in AI/ML, making integration with models seamless. FastAPI offers high performance and automatic API documentation (Swagger UI), while Flask is lightweight and flexible, both ideal for serving AI model inference and managing business logic.\n    *   **Image Processing:** **Pillow (PIL Fork)** and **OpenCV** (Python libraries for image manipulation, resizing, and pre-processing before feeding to ML models).\n\n*   **Database (Data Storage)**\n    *   **Type:** **Relational Database**\n    *   **Technology:** **PostgreSQL** or **MySQL**\n    *   **Reasoning:** These are robust, open-source relational databases well-suited for storing structured data such as:\n        *   Disease information (name, symptoms, description, impact).\n        *   Solution/treatment recommendations (pesticides, organic methods, prevention).\n        *   Crop types.\n        *   User data (if authentication/profiles are implemented).\n        *   Environmental data (if integrated as per SIH1638).\n\n*   **AI/ML Tools (Model Training & Inference)**\n    *   **Deep Learning Frameworks:** **TensorFlow** or **PyTorch**\n    *   **Reasoning:** These are industry-standard deep learning libraries, essential for building and training Convolutional Neural Networks (CNNs) for image classification (identifying diseases from leaf images).\n    *   **High-Level API (for TensorFlow):** **Keras** (simplifies model definition and training within TensorFlow).\n    *   **Model Deployment:** **TensorFlow Serving** or custom API endpoints using FastAPI/Flask to serve the trained models for real-time predictions.\n\n*   **Deployment (Infrastructure & Hosting)**\n    *   **Cloud Platform:** **AWS (Amazon Web Services)**, **Google Cloud Platform (GCP)**, or **Microsoft Azure**.\n    *   **Reasoning:** These provide scalable, reliable, and secure infrastructure.\n        *   **Compute:** **AWS EC2 / GCP Compute Engine / Azure Virtual Machines** (for hosting backend and ML services).\n        *   **Storage:** **AWS S3 / GCP Cloud Storage / Azure Blob Storage** (for storing raw leaf images, processed images, and trained ML models).\n        *   **Database Service:** **AWS RDS (PostgreSQL/MySQL) / GCP Cloud SQL / Azure Database for PostgreSQL/MySQL**.\n        *   **ML Services:** **AWS SageMaker / GCP AI Platform / Azure Machine Learning** (for streamlined model training, deployment, and management).\n        *   **Containerization:** **Docker** (for packaging the application and ML models for consistent deployment across environments).\n        *   **Orchestration (optional for scale):** **Kubernetes** (for managing containerized applications in production).\n\n*   **APIs (Communication Layer)**\n    *   **Type:** **RESTful APIs**\n    *   **Reasoning:** RESTful APIs are the standard for communication between the frontend (mobile/web) and the backend services. They  ...
# {'answer': 'Based on the provided context from SIH1638 and CropStetho, here is a complete system architecture for an AI Crop Disease Detection system:\n\n### **System Architecture for AI Crop Disease Detection**\n\nThe system aims to leverage Artificial Intelligence to help farmers quickly and accurately diagnose crop diseases, provide treatment recommendations, and potentially predict outbreaks.\n\n### **1. Components**\n\nThe system can be logically divided into the following key components:\n\n*   **User Interface (UI) - Frontend Applications:**\n    *   **Mobile Application (Android/iOS):** Primary interface for farmers to capture/upload images, receive diagnoses, view recommendations, and access historical data. (As mentioned in CropStetho: "An app that the farmer can have their smartphone").\n    *   **Web Application:** An alternative interface for farmers, and potentially for administrators or agricultural experts to manage the knowledge base, view aggregated data, and access advanced features. (As mentioned in SIH1638: "A mobile and web-based application").\n*   **Backend Services (Microservices Architecture):**\n    *   **API Gateway:** Acts as the single entry point for all client requests, handling authentication, rate limiting, and routing requests to appropriate microservices.\n    *   **User Management Service:** Handles user registration, login, profile management, and authentication/authorization.\n    *   **Image Processing Service:** Receives uploaded images, performs pre-processing (resizing, cropping, normalization), and stores them.\n    *   **AI/ML Inference Service:** Hosts the trained Deep Learning models for plant identification and disease classification. It receives processed images and returns predictions.\n    *   **Data Management Service:** Manages all interactions with the database, including storing diagnosis history, crop information, and retrieving knowledge base data.\n    *   **Knowledge Base & Recommendation Service:** Stores detailed information about crop diseases (symptoms, causes), treatment options, and preventive measures. It generates recommendations based on the AI diagnosis. (As mentioned in CropStetho: "Provide treatment options by pulling information from the database and attaching links to online sources").\n    *   **Environmental Data Integration Service (SIH1638 Specific):** Integrates with external APIs (e.g., weather APIs) or IoT devices to collect real-time environmental data (temperature, humidity, rainfall) for predictive analysis.\n    *   **Notification Service:** Manages sending alerts, diagnosis confirmations, or updates to users via push notifications, SMS, or email.\n*   **Databases:**\n    *   **Relational Database (e.g., PostgreSQL, MySQL):** Stores structured data such as user profiles, crop types, disease descriptions, treatment protocols, historical diagnosis records, and environmental data.\n    *   **Object Storage (e.g., AWS S3, Azure Blob Storage):** Stores raw and processed crop images efficiently.\n*   **AI/ML Platform:**\n    *   **Model Training & Management Environment:** Infrastructure for developing, training, evaluating, and versioning Deep Learning models. (As mentioned in CropStetho: "Deep Learning pipeline," "Adapt a pretrained model... AlexNet," "Pytorch").\n\n### **2. User Flow**\n\nHere\'s a typical user interaction flow for a farmer using the mobile application:\n\n1.  **Authentication:** The farmer opens the mobile app and either **Signs Up** for a new account or **Logs In** with existing credentials.\n2.  **Crop Selection (Optional):** The farmer may select the specific crop they are monitoring from a list (e.g., "Tomato," "Potato"). This can help refine predictions.\n3.  **Capture/Upload Image:** The farmer uses the app\'s camera to take a clear picture of the affected plant leaf/part or selects an image from their device\'s gallery.\n4.  **Image Upload & Processing:** The app uploads the image to the backend. The Image Processing Servi ...
# {'answer': 'Here\'s a 45-second elevator pitch for AI Crop Disease Detection:\n\n"Did you know crop diseases devastate agriculture, causing up to 40% of global food supply loss annually? For farmers, especially smallholders, this means catastrophic financial losses, sometimes their entire harvest, threatening global food security. Current diagnosis methods are often slow and inaccurate.\n\nOur AI Crop Disease Detection system, a mobile and web app, leverages machine learning to analyze crop images and environmental data. It accurately predicts disease outbreaks and delivers real-time, actionable insights with preventive measures and precise treatment recommendations.\n\nThis empowers farmers to intervene early, drastically reducing crop loss, boosting yields, and ensuring greater food security. We\'re transforming disease management from reactive to proactive.\n\nReady to secure the future of our food? Let\'s grow smarter, together."', 'sources': ['..\\data\\winning_projects\\cropStetho.pdf (Page 2)', '..\\data\\problem_statements\\problem_statement_2.pdf (Page 1)']}

# %%
from langchain_community.document_loaders import WebBaseLoader

# %%
with open("C:\\Users\\Niharika\\Hackathon rag\\data\\urls\\urls.txt", "r") as f:
    urls = [
        line.strip()
        for line in f
        if line.strip()
    ]

print(urls)
# Out:
# ['https://firebase.google.com/docs', 'https://huggingface.co/docs', 'https://developers.google.com/maps/documentation', 'https://docs.aws.amazon.com', 'https://platform.openai.com/docs']

# %%
import os

path = r"C:\Users\Niharika\Hackathon rag\data\urls\urls.txt"

print(os.path.exists(path))
# Out:
# True

# %%
all_url_docs = []

for url in urls:

    try:
        loader = WebBaseLoader(url)

        docs = loader.load()

        all_url_docs.extend(docs)

        print(f"Loaded: {url}")

    except Exception as e:

        print(f"Failed: {url}")

        print(e)
# Out:
# Loaded: https://firebase.google.com/docs
# Loaded: https://huggingface.co/docs
# Loaded: https://developers.google.com/maps/documentation
# Loaded: https://docs.aws.amazon.com
# Loaded: https://platform.openai.com/docs

# %%
len(all_url_docs)
# Out:
# 5

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

# %%
url_chunks = text_splitter.split_documents(
    all_url_docs
)

print(len(url_chunks))
# Out:
# 82

# %%
vector_store.add_documents(
    url_chunks
)

print("URL ingestion completed")
# Out:
# URL ingestion completed

# %%
result = ask_rag(
    "What is Firebase?"
)

print(result)
# Out:
# {'answer': 'Based on the provided context, Firebase is a **suite of products** designed to help developers:\n\n*   **Build** their apps.\n*   **Harness AI** by using Firebase and Gemini together for faster, easier, and better development, and to build AI-powered experiences.\n*   **Run** their apps with confidence, delivering the best user experience through AI-assistive tools for launching, monitoring, and iterating. This includes improving app stability and performance, iterating dynamically, collecting user feedback, understanding and engaging with users, and optimizing/personalizing user experience.\n\nIt also offers extensive developer documentation and learning content to help users become skillful with its products.', 'sources': ['https://firebase.google.com/docs (Page N/A)']}

# %%
docs = retriever.invoke(
    "What is Firebase?"
)

print(docs[0].metadata)
# Out:
# {'source': 'https://firebase.google.com/docs', 'title': 'Firebase Documentation', 'description': 'Developer documentation for Firebase', 'language': 'en', '_id': '19b7c6cd-75ff-42ce-9af7-0e81232de827', '_collection_name': 'hackathon_docs'}
